# %%
import pandas as pd
import matplotlib.pyplot as plt


# Plt Style
plt.style.use('bmh')

# DataFrame
df = pd.read_csv(r"D:\Python Course\Playing Matplotlib\csv\data1.csv")

# Col
ages = df["Age"]
devs = df["All_Devs"]
py_Sal = df["Python"]
js_Sal = df["JavaScript"]

# %%
# plt.gca()
# plt.gcf()

fig, (ax1, ax2) = plt.subplots(nrows = 2, ncols = 1, sharex = True)

ax1.plot(ages, devs, linestyle='--', color='black', linewidth=1.5, label="All Dev's")

ax1.legend()
ax1.set_title("Programmer Median Salary (USD)", loc='left',)

ax2.plot(ages, py_Sal, color='blue', label="Py Dev's", linewidth=1.5)
ax2.plot(ages, js_Sal, color='orange', label="Js Dev's", linewidth=1.5)
ax2.legend()
ax2.set_xlabel("Ages", loc='center', labelpad=20)
ax2.set_ylabel("Salary", labelpad=20, loc='top')
# Out:
# Text(0, 1, 'Salary')
