# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mpl_dates
from datetime import datetime, timedelta
import pandas as pd

plt.style.use('bmh')

# %%
# Plot Time

plt.figure(figsize=(8, 6))
dates = [
    datetime(2020,7,18),
    datetime(2020,7,19),
    datetime(2020,7,20),
    datetime(2020,7,21),
    datetime(2020,7,22),
    datetime(2020,7,23),
    datetime(2020,7,24),
    datetime(2020,7,25)
]

y = [0, 1, 2, 3, 6, 7, 5, 8]

# Date Formatting
plt.plot_date(dates, y, linestyle='solid')
plt.gcf().autofmt_xdate()

dateFormat = mpl_dates.DateFormatter('%b, %d %Y')
plt.gca().xaxis.set_major_formatter(dateFormat)

plt.tight_layout()
# Out:
# C:\Users\Diandra\AppData\Local\Temp\ipykernel_19172\1094023105.py:18: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(dates, y, linestyle='solid')

# %%
# Plot Time w/ Data
plt.figure(figsize=(15, 13))
df = pd.read_csv(r"D:\Python Course\Playing Matplotlib\csv\data3.csv")
df["Date"] = pd.to_datetime(df["Date"])
df.sort_values("Date", inplace=True)


date = df["Date"]
Close = df["Close"]

plt.plot_date(date, Close, linestyle="solid")
plt.gcf().autofmt_xdate()
dateFormatt = mpl_dates.DateFormatter("%b, %d %Y")
plt.gca().xaxis.set_major_formatter(dateFormat)

plt.title("Bitcoin Prices Track")
plt.xlabel("Closing Prices", labelpad=50)
plt.ylabel("Date", labelpad=50)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Diandra\AppData\Local\Temp\ipykernel_19172\3265624394.py:11: MatplotlibDeprecationWarning: The plot_date function was deprecated in Matplotlib 3.9 and will be removed in 3.11. Use plot instead.
#   plt.plot_date(date, Close, linestyle="solid")
