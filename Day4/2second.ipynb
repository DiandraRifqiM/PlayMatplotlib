# %%
import matplotlib.pyplot as plt
import pandas as pd

plt.style.use("bmh")

df = pd.read_csv(r"D:\Python Course\Playing Matplotlib\csv\data1.csv")
ages = df["Age"]
Py = df["Python"]
Js = df["JavaScript"]
All = df["All_Devs"]

# ovr_median = 57287

plt.plot(ages, All, linestyle="--", color="blue", label="All Dev")

plt.plot(ages, Py, color="#1d85e0", label="Python")

plt.fill_between(ages, Py, All, color="#1d85e0", where=(Py > ovr_median), interpolate=True, alpha=0.3, label="Above Average")
plt.fill_between(ages, Py, All, interpolate=True, color="orange", where=(Py <= All), alpha=0.3, label="Below Average")

plt.legend()
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.title("Median Salary by Age")
plt.tight_layout()

# %%
df.median()
# Out:
# Age              36.5
# All_Devs      77616.0
# Python        84016.0
# JavaScript    78754.0
# dtype: float64
